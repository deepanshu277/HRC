# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import cv2
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
import random

from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop,Adam
from sklearn.model_selection import train_test_split
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %% [markdown]
# # Loading the data
# * Gven dataset has training,validation and test set, but validation set has only 16 images whereas training set has 5216 images.
# * So first we need to create a proper distribution set with 80% as training data and 20% as validation data.
# * So we'll merge training and validation set and then split them in the ratio of 80:20 repectively.

# %%
BASE_DIR=('../input/chest-xray-pneumonia/chest_xray/')
train_dir=os.path.join(BASE_DIR,'train/')
val_dir=os.path.join(BASE_DIR,'val/')
test_dir=os.path.join(BASE_DIR,'test/')

print('Number of images in training set = ',str(len(glob(train_dir+'*/*'))))
print('Number of images in validation set = ',str(len(glob(val_dir+'*/*'))))
print('Number of images in testing set = ',str(len(glob(test_dir+'*/*'))))
# Out:
# Number of images in training set =  5216
# Number of images in validation set =  16
# Number of images in testing set =  624

# %%
training_images = tf.io.gfile.glob('../input/chest-xray-pneumonia/chest_xray/train/*/*')
validation_images = tf.io.gfile.glob('../input/chest-xray-pneumonia/chest_xray/val/*/*')


total_files = training_images
total_files.extend(validation_images)
print(f'Total number of images : training_images + validation_images = {len(total_files)}\n')

#spliting 80:20
train_images, val_images = train_test_split(total_files, test_size = 0.2)
print(f'After division of 80:20')
print(f'Total number of training images = {len(train_images)}')
print(f'Total number of validation images = {len(val_images)}')
# Out:
# Total number of images : training_images + validation_images = 5232
#
# After division of 80:20
# Total number of training images = 4185
# Total number of validation images = 1047

# %% [markdown]
# ## Making new directories for training set and validation set

# %%
tf.io.gfile.makedirs('/kaggle/working/val_dataset/NORMAL/')
tf.io.gfile.makedirs('/kaggle/working/val_dataset/PNEUMONIA/')
tf.io.gfile.makedirs('/kaggle/working/train_dataset/NORMAL/')
tf.io.gfile.makedirs('/kaggle/working/train_dataset/PNEUMONIA/')

# %% [markdown]
# ## Copying the images in new directories

# %%
for ele in train_images:
    parts_of_path = ele.split('/')

    if 'PNEUMONIA' == parts_of_path[-2]:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/train_dataset/PNEUMONIA/' +  parts_of_path[-1])
    else:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/train_dataset/NORMAL/' +  parts_of_path[-1])

# %%
for ele in val_images:
    parts_of_path = ele.split('/')

    if 'PNEUMONIA' == parts_of_path[-2]:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/val_dataset/PNEUMONIA/' +  parts_of_path[-1])
    else:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/val_dataset/NORMAL/' +  parts_of_path[-1])

# %%
print('Pneumonia x-ray images in training set after split = ',len(os.listdir('/kaggle/working/train_dataset/PNEUMONIA/')))
print('Normal x-ray images in training set after split = ',len(os.listdir('/kaggle/working/train_dataset/NORMAL/')))
print('Pneumonia x-ray images in validation set after split = ',len(os.listdir('/kaggle/working/val_dataset/PNEUMONIA/')))
print('Normal x-ray images in validation set after split = ',len(os.listdir('/kaggle/working/val_dataset/NORMAL/')))
print('Pneumonia x-ray images in test set = ',len(os.listdir('../input/chest-xray-pneumonia/chest_xray/test/PNEUMONIA/')))
print('Normal x-ray images in test set = ',len(os.listdir('../input/chest-xray-pneumonia/chest_xray/test/NORMAL')))
# Out:
# Pneumonia x-ray images in training set after split =  3100
# Normal x-ray images in training set after split =  1085
# Pneumonia x-ray images in validation set after split =  783
# Normal x-ray images in validation set after split =  264
# Pneumonia x-ray images in test set =  390
# Normal x-ray images in test set =  234

# %% [markdown]
# ## Setting the path of training directory and validation directory

# %%
train_dir='/kaggle/working/train_dataset/'
val_dir='/kaggle/working/val_dataset/'
test_dir='../input/chest-xray-pneumonia/chest_xray/test/'

train_normal_dir='/kaggle/working/train_dataset/NORMAL'
train_pneumonia_dir='/kaggle/working/train_dataset/PNEUMONIA'
val_normal_dir='/kaggle/working/val_dataset/NORMAL'
val_pneumonia_dir='/kaggle/working/val_dataset/PNEUMONIA'

# %%
train_normal_fnames=os.listdir(train_normal_dir)
train_pneumonia_fnames=os.listdir(train_pneumonia_dir)

print(train_normal_fnames[:10])
print(train_pneumonia_fnames[:10])
# Out:
# ['IM-0646-0001.jpeg', 'IM-0504-0001.jpeg', 'NORMAL2-IM-0995-0001.jpeg', 'IM-0540-0001.jpeg', 'NORMAL2-IM-0630-0001.jpeg', 'NORMAL2-IM-1198-0001.jpeg', 'IM-0513-0001.jpeg', 'IM-0527-0001.jpeg', 'NORMAL2-IM-1345-0001-0001.jpeg', 'NORMAL2-IM-0924-0001.jpeg']
# ['person1345_bacteria_3426.jpeg', 'person789_virus_1420.jpeg', 'person1212_bacteria_3164.jpeg', 'person1642_bacteria_4353.jpeg', 'person1628_bacteria_4294.jpeg', 'person392_bacteria_1786.jpeg', 'person1546_bacteria_4045.jpeg', 'person30_bacteria_157.jpeg', 'person1100_virus_1820.jpeg', 'person833_virus_1469.jpeg']

# %% [markdown]
# ## Visualizing pneumonia x-ray images and normal x-ray images

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

no_cols=4
no_rows=4

pic_index=0

# %%
fig=plt.gcf()
fig.set_size_inches(no_cols*4,no_rows*4)

pic_index+=8

normal_pix=[os.path.join(train_normal_dir,fname) for fname in train_normal_fnames[pic_index-8:pic_index]]
pneumonia_pix=[os.path.join(train_pneumonia_dir,fname) for fname in train_pneumonia_fnames[pic_index-8:pic_index]]

for i,img_path in enumerate(normal_pix+pneumonia_pix):
    sp=plt.subplot(no_rows,no_cols,i+1)
    sp.axis()
    
    img=mpimg.imread(img_path)
    plt.imshow(img,cmap='gray')
    
plt.show()

# first 8 images are normal x-ray images and next 8 images are pnemonia x-ray images

# %% [markdown]
# # Model 1
# ### First model which we are going to train is a simple CNN model.

# %%
model=tf.keras.models.Sequential([
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu',padding='same', input_shape=(180, 180, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu',padding='same'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer=RMSprop(lr=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy','Precision','Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 180, 180, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               819712
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 917,377
# Trainable params: 917,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_datagen=ImageDataGenerator(rescale=1.0/255,
                                 rotation_range=30,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 zoom_range=0.2,
                                 )

val_datagen=ImageDataGenerator(rescale=1.0/255)

test_datagen=ImageDataGenerator(rescale=1.0/255)

train_generator=train_datagen.flow_from_directory(train_dir,color_mode="grayscale",target_size=(180,180),batch_size=128,class_mode='binary')

val_generator=val_datagen.flow_from_directory(val_dir,color_mode="grayscale",target_size=(180,180),batch_size=128,class_mode='binary')

test_generator=test_datagen.flow_from_directory(test_dir,color_mode="grayscale",target_size=(180,180),batch_size=128,class_mode='binary')
# Out:
# Found 4185 images belonging to 2 classes.
# Found 1047 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
history=model.fit(train_generator,validation_data=val_generator,epochs=30,verbose=2)
# Out:
# Epoch 1/30
# 33/33 - 59s - loss: 0.5687 - accuracy: 0.7326 - precision: 0.7466 - recall: 0.9674 - val_loss: 0.7151 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 2/30
# 33/33 - 58s - loss: 0.4649 - accuracy: 0.7472 - precision: 0.7718 - recall: 0.9352 - val_loss: 0.3583 - val_accuracy: 0.7937 - val_precision: 0.7867 - val_recall: 0.9936
# Epoch 3/30
# 33/33 - 57s - loss: 0.3858 - accuracy: 0.8122 - precision: 0.8652 - recall: 0.8842 - val_loss: 0.2953 - val_accuracy: 0.8940 - val_precision: 0.9409 - val_recall: 0.9157
# Epoch 4/30
# 33/33 - 56s - loss: 0.3819 - accuracy: 0.8196 - precision: 0.8647 - recall: 0.8968 - val_loss: 0.3210 - val_accuracy: 0.8615 - val_precision: 0.9878 - val_recall: 0.8250
# Epoch 5/30
# 33/33 - 57s - loss: 0.3372 - accuracy: 0.8425 - precision: 0.8964 - recall: 0.8903 - val_loss: 0.3278 - val_accuracy: 0.8539 - val_precision: 0.9953 - val_recall: 0.8084
# Epoch 6/30
# 33/33 - 55s - loss: 0.3323 - accuracy: 0.8485 - precision: 0.8993 - recall: 0.8958 - val_loss: 0.5901 - val_accuracy: 0.6982 - val_precision: 1.0000 - val_recall: 0.5964
# Epoch 7/30
# 33/33 - 55s - loss: 0.3021 - accuracy: 0.8648 - precision: 0.9146 - recall: 0.9016 - val_loss: 0.2259 - val_accuracy: 0.9016 - val_precision: 0.9087 - val_recall: 0.9655
# Epoch 8/30
# 33/33 - 54s - loss: 0.2807 - accuracy: 0.8798 - precision: 0.9195 - recall: 0.9181 - val_loss: 0.2946 - val_accuracy: 0.8930 - val_precision: 0.9813 - val_recall: 0.8736
# Epoch 9/30
# 33/33 - 54s - loss: 0.2761 - accuracy: 0.8855 - precision: 0.9240 - recall: 0.9213 - val_loss: 0.3634 - val_accuracy: 0.8539 - val_precision: 0.9922 - val_recall: 0.8110
# Epoch 10/30
# 33/33 - 55s - loss: 0.2671 - accuracy: 0.8906 - precision: 0.9289 - recall: 0.9229 - val_loss: 0.2483 - val_accuracy: 0.9074 - val_precision: 0.9900 - val_recall: 0.8851
# Epoch 11/30
# 33/33 - 54s - loss: 0.2446 - accuracy: 0.8982 - precision: 0.9344 - recall: 0.9277 - val_loss: 0.2700 - val_accuracy: 0.8701 - val_precision: 0.8590 - val_recall: 0.9885
# Epoch 12/30
# 33/33 - 54s - loss: 0.2270 - accuracy: 0.9075 - precision: 0.9355 - recall: 0.9400 - val_loss: 0.1716 - val_accuracy: 0.9236 - val_precision: 0.9944 - val_recall: 0.9029
# Epoch 13/30
# 33/33 - 54s - loss: 0.2352 - accuracy: 0.9073 - precision: 0.9420 - recall: 0.9323 - val_loss: 0.1325 - val_accuracy: 0.9465 - val_precision: 0.9777 - val_recall: 0.9502
# Epoch 14/30
# 33/33 - 54s - loss: 0.2120 - accuracy: 0.9157 - precision: 0.9446 - recall: 0.9413 - val_loss: 0.1879 - val_accuracy: 0.9226 - val_precision: 0.9958 - val_recall: 0.9004
# Epoch 15/30
# 33/33 - 54s - loss: 0.2073 - accuracy: 0.9228 - precision: 0.9504 - recall: 0.9452 - val_loss: 0.1341 - val_accuracy: 0.9503 - val_precision: 0.9906 - val_recall: 0.9425
# Epoch 16/30
# 33/33 - 56s - loss: 0.1992 - accuracy: 0.9233 - precision: 0.9504 - recall: 0.9458 - val_loss: 0.1147 - val_accuracy: 0.9522 - val_precision: 0.9741 - val_recall: 0.9617
# Epoch 17/30
# 33/33 - 55s - loss: 0.1935 - accuracy: 0.9231 - precision: 0.9501 - recall: 0.9458 - val_loss: 0.2183 - val_accuracy: 0.8968 - val_precision: 0.8796 - val_recall: 0.9987
# Epoch 18/30
# 33/33 - 54s - loss: 0.2037 - accuracy: 0.9204 - precision: 0.9464 - recall: 0.9461 - val_loss: 0.1445 - val_accuracy: 0.9408 - val_precision: 0.9918 - val_recall: 0.9285
# Epoch 19/30
# 33/33 - 55s - loss: 0.1693 - accuracy: 0.9314 - precision: 0.9571 - recall: 0.9500 - val_loss: 0.1926 - val_accuracy: 0.9236 - val_precision: 0.9958 - val_recall: 0.9017
# Epoch 20/30
# 33/33 - 55s - loss: 0.1835 - accuracy: 0.9309 - precision: 0.9559 - recall: 0.9506 - val_loss: 0.1553 - val_accuracy: 0.9389 - val_precision: 0.9931 - val_recall: 0.9246
# Epoch 21/30
# 33/33 - 55s - loss: 0.1619 - accuracy: 0.9362 - precision: 0.9622 - recall: 0.9513 - val_loss: 0.1428 - val_accuracy: 0.9436 - val_precision: 0.9469 - val_recall: 0.9796
# Epoch 22/30
# 33/33 - 55s - loss: 0.1612 - accuracy: 0.9374 - precision: 0.9583 - recall: 0.9571 - val_loss: 0.1538 - val_accuracy: 0.9379 - val_precision: 0.9904 - val_recall: 0.9259
# Epoch 23/30
# 33/33 - 55s - loss: 0.1753 - accuracy: 0.9321 - precision: 0.9539 - recall: 0.9545 - val_loss: 0.1261 - val_accuracy: 0.9494 - val_precision: 0.9932 - val_recall: 0.9387
# Epoch 24/30
# 33/33 - 55s - loss: 0.1547 - accuracy: 0.9410 - precision: 0.9633 - recall: 0.9568 - val_loss: 0.1126 - val_accuracy: 0.9542 - val_precision: 0.9706 - val_recall: 0.9681
# Epoch 25/30
# 33/33 - 55s - loss: 0.1552 - accuracy: 0.9424 - precision: 0.9631 - recall: 0.9590 - val_loss: 0.1039 - val_accuracy: 0.9551 - val_precision: 0.9829 - val_recall: 0.9566
# Epoch 26/30
# 33/33 - 54s - loss: 0.1469 - accuracy: 0.9448 - precision: 0.9638 - recall: 0.9616 - val_loss: 0.1044 - val_accuracy: 0.9580 - val_precision: 0.9830 - val_recall: 0.9604
# Epoch 27/30
# 33/33 - 54s - loss: 0.1635 - accuracy: 0.9355 - precision: 0.9576 - recall: 0.9552 - val_loss: 0.1657 - val_accuracy: 0.9331 - val_precision: 0.9945 - val_recall: 0.9157
# Epoch 28/30
# 33/33 - 54s - loss: 0.1423 - accuracy: 0.9431 - precision: 0.9649 - recall: 0.9581 - val_loss: 0.1137 - val_accuracy: 0.9580 - val_precision: 0.9805 - val_recall: 0.9630
# Epoch 29/30
# 33/33 - 54s - loss: 0.1459 - accuracy: 0.9453 - precision: 0.9647 - recall: 0.9613 - val_loss: 0.1459 - val_accuracy: 0.9446 - val_precision: 0.9905 - val_recall: 0.9349
# Epoch 30/30
# 33/33 - 54s - loss: 0.1422 - accuracy: 0.9462 - precision: 0.9678 - recall: 0.9594 - val_loss: 0.0976 - val_accuracy: 0.9628 - val_precision: 0.9895 - val_recall: 0.9604

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

train_precision=history.history['precision']
val_precision=history.history['val_precision']

train_recall=history.history['recall']
val_recall=history.history['val_recall']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, train_precision, 'r', label='Training precision')
plt.plot(epochs, val_precision, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.figure()

plt.plot(epochs, train_recall, 'r', label='Training recall')
plt.plot(epochs, val_recall, 'b', label='Validation recall')
plt.title('Training and validation recall')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
eval_result1 = model.evaluate_generator(test_generator, 624)
print('loss  :', eval_result1[0])
print('accuracy  :', eval_result1[1])
print('Precision :', eval_result1[2])
print('Recall :', eval_result1[3])
# Out:
# loss  : 0.41598594188690186
# accuracy  : 0.8910256624221802
# Precision : 0.859375
# Recall : 0.9871794581413269

# %% [markdown]
# # Model 2 (ResNet-50)
#  * We'll user pre-trained model provided by keras and add some layers on the top.
#  * The pre-trained ResNet model in keras takes in input of exactly three input channel, but our input image is of grayscale.
#  * So inorder to avoid mismatch of shape we'll let our Image data generator use the default color_mode ie rgb instead of specifying it to be gray_scale.

# %%
train_datagen2=ImageDataGenerator(rescale=1.0/255,
                                 rotation_range=30,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 zoom_range=0.2,
                                 )

val_datagen2=ImageDataGenerator(rescale=1.0/255)

test_datagen2=ImageDataGenerator(rescale=1.0/255)

train_generator2=train_datagen2.flow_from_directory(train_dir,target_size=(180,180),batch_size=128,class_mode='binary')

val_generator2=val_datagen2.flow_from_directory(val_dir,target_size=(180,180),batch_size=128,class_mode='binary')

test_generator2=test_datagen2.flow_from_directory(test_dir,target_size=(180,180),batch_size=128,class_mode='binary')
# Out:
# Found 4185 images belonging to 2 classes.
# Found 1047 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# ## Importing and loading pretrained ResNet50 model

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
pretrained_model2 = ResNet50(weights= 'imagenet', include_top=False, input_shape= (180,180,3))

#freazing the trained layers
for layers in pretrained_model2.layers:
    layers.trainable = False
#pretrained_model3.summary()

# %%
last_layer=pretrained_model2.get_layer('conv5_block3_1_relu')
last_output = last_layer.output

x=tf.keras.layers.Flatten()(last_output)
x=tf.keras.layers.Dense(1024,activation='relu')(x)
x=tf.keras.layers.Dropout(0.2)(x)
x=tf.keras.layers.Dense(256,activation='relu')(x)
x=tf.keras.layers.Dropout(0.2)(x)
x=tf.keras.layers.Dense(1,activation='sigmoid')(x)

model2=tf.keras.Model(pretrained_model2.input,x)

model2.compile(optimizer=RMSprop(lr=0.001),
              loss='binary_crossentropy',
               metrics=['accuracy','Precision','Recall'])

#model3.summary()

# %%
history2=model2.fit(train_generator2,validation_data=val_generator2,epochs=30,verbose=2)
# Out:
# Epoch 1/30
# 33/33 - 82s - loss: 1.1911 - accuracy: 0.7020 - precision: 0.7386 - recall: 0.9252 - val_loss: 0.6348 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 2/30
# 33/33 - 79s - loss: 0.5922 - accuracy: 0.7376 - precision: 0.7403 - recall: 0.9948 - val_loss: 0.5739 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 3/30
# 33/33 - 80s - loss: 0.5804 - accuracy: 0.7410 - precision: 0.7411 - recall: 0.9994 - val_loss: 0.5695 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 4/30
# 33/33 - 78s - loss: 0.5727 - accuracy: 0.7407 - precision: 0.7407 - recall: 1.0000 - val_loss: 0.5341 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 5/30
# 33/33 - 77s - loss: 0.5565 - accuracy: 0.7407 - precision: 0.7407 - recall: 1.0000 - val_loss: 0.5373 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 6/30
# 33/33 - 79s - loss: 0.5386 - accuracy: 0.7407 - precision: 0.7407 - recall: 1.0000 - val_loss: 0.5103 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 7/30
# 33/33 - 79s - loss: 0.5361 - accuracy: 0.7407 - precision: 0.7407 - recall: 1.0000 - val_loss: 0.5457 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 8/30
# 33/33 - 78s - loss: 0.5115 - accuracy: 0.7441 - precision: 0.7465 - recall: 0.9910 - val_loss: 0.4851 - val_accuracy: 0.7498 - val_precision: 0.7493 - val_recall: 1.0000
# Epoch 9/30
# 33/33 - 79s - loss: 0.5064 - accuracy: 0.7505 - precision: 0.7684 - recall: 0.9494 - val_loss: 0.5292 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 10/30
# 33/33 - 79s - loss: 0.4880 - accuracy: 0.7577 - precision: 0.7839 - recall: 0.9290 - val_loss: 0.4918 - val_accuracy: 0.7813 - val_precision: 0.8713 - val_recall: 0.8301
# Epoch 11/30
# 33/33 - 79s - loss: 0.4967 - accuracy: 0.7441 - precision: 0.7786 - recall: 0.9145 - val_loss: 0.5291 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 12/30
# 33/33 - 79s - loss: 0.4902 - accuracy: 0.7546 - precision: 0.7966 - recall: 0.8981 - val_loss: 0.5025 - val_accuracy: 0.7851 - val_precision: 0.9067 - val_recall: 0.7944
# Epoch 13/30
# 33/33 - 77s - loss: 0.4843 - accuracy: 0.7522 - precision: 0.8033 - recall: 0.8813 - val_loss: 0.4791 - val_accuracy: 0.7899 - val_precision: 0.9050 - val_recall: 0.8033
# Epoch 14/30
# 33/33 - 78s - loss: 0.4754 - accuracy: 0.7675 - precision: 0.8200 - recall: 0.8790 - val_loss: 0.4207 - val_accuracy: 0.7584 - val_precision: 0.7645 - val_recall: 0.9783
# Epoch 15/30
# 33/33 - 79s - loss: 0.4619 - accuracy: 0.7608 - precision: 0.8117 - recall: 0.8816 - val_loss: 0.4469 - val_accuracy: 0.7927 - val_precision: 0.9008 - val_recall: 0.8123
# Epoch 16/30
# 33/33 - 78s - loss: 0.4759 - accuracy: 0.7577 - precision: 0.8123 - recall: 0.8752 - val_loss: 0.4359 - val_accuracy: 0.7564 - val_precision: 0.7629 - val_recall: 0.9783
# Epoch 17/30
# 33/33 - 77s - loss: 0.4704 - accuracy: 0.7637 - precision: 0.8174 - recall: 0.8768 - val_loss: 0.4065 - val_accuracy: 0.8118 - val_precision: 0.8513 - val_recall: 0.9068
# Epoch 18/30
# 33/33 - 77s - loss: 0.4527 - accuracy: 0.7742 - precision: 0.8292 - recall: 0.8755 - val_loss: 0.5228 - val_accuracy: 0.7192 - val_precision: 0.9729 - val_recall: 0.6424
# Epoch 19/30
# 33/33 - 78s - loss: 0.4588 - accuracy: 0.7658 - precision: 0.8331 - recall: 0.8552 - val_loss: 0.3954 - val_accuracy: 0.8013 - val_precision: 0.8219 - val_recall: 0.9374
# Epoch 20/30
# 33/33 - 77s - loss: 0.4535 - accuracy: 0.7603 - precision: 0.8286 - recall: 0.8529 - val_loss: 0.4077 - val_accuracy: 0.8109 - val_precision: 0.8990 - val_recall: 0.8416
# Epoch 21/30
# 33/33 - 78s - loss: 0.4568 - accuracy: 0.7730 - precision: 0.8285 - recall: 0.8745 - val_loss: 0.3979 - val_accuracy: 0.8090 - val_precision: 0.8999 - val_recall: 0.8378
# Epoch 22/30
# 33/33 - 77s - loss: 0.4541 - accuracy: 0.7775 - precision: 0.8340 - recall: 0.8735 - val_loss: 0.4058 - val_accuracy: 0.7660 - val_precision: 0.7712 - val_recall: 0.9770
# Epoch 23/30
# 33/33 - 78s - loss: 0.4563 - accuracy: 0.7761 - precision: 0.8333 - recall: 0.8723 - val_loss: 0.4141 - val_accuracy: 0.8185 - val_precision: 0.8806 - val_recall: 0.8761
# Epoch 24/30
# 33/33 - 78s - loss: 0.4383 - accuracy: 0.7766 - precision: 0.8322 - recall: 0.8748 - val_loss: 0.4963 - val_accuracy: 0.7574 - val_precision: 0.9681 - val_recall: 0.6986
# Epoch 25/30
# 33/33 - 78s - loss: 0.4343 - accuracy: 0.7881 - precision: 0.8534 - recall: 0.8619 - val_loss: 0.3751 - val_accuracy: 0.8138 - val_precision: 0.8403 - val_recall: 0.9272
# Epoch 26/30
# 33/33 - 79s - loss: 0.4451 - accuracy: 0.7806 - precision: 0.8424 - recall: 0.8658 - val_loss: 0.4286 - val_accuracy: 0.7994 - val_precision: 0.9484 - val_recall: 0.7739
# Epoch 27/30
# 33/33 - 78s - loss: 0.4409 - accuracy: 0.7802 - precision: 0.8389 - recall: 0.8703 - val_loss: 0.3955 - val_accuracy: 0.7775 - val_precision: 0.7812 - val_recall: 0.9757
# Epoch 28/30
# 33/33 - 78s - loss: 0.4338 - accuracy: 0.7859 - precision: 0.8452 - recall: 0.8703 - val_loss: 0.4214 - val_accuracy: 0.7880 - val_precision: 0.7919 - val_recall: 0.9719
# Epoch 29/30
# 33/33 - 78s - loss: 0.4268 - accuracy: 0.7854 - precision: 0.8415 - recall: 0.8752 - val_loss: 0.3648 - val_accuracy: 0.8243 - val_precision: 0.8702 - val_recall: 0.8991
# Epoch 30/30
# 33/33 - 80s - loss: 0.4290 - accuracy: 0.7878 - precision: 0.8437 - recall: 0.8758 - val_loss: 0.5919 - val_accuracy: 0.6342 - val_precision: 0.9926 - val_recall: 0.5147

# %%
acc2 = history2.history['accuracy']
val_acc2 = history2.history['val_accuracy']

train_precision2=history2.history['precision']
val_precision2=history2.history['val_precision']

train_recall2=history2.history['recall']
val_recall2=history2.history['val_recall']

loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']
epochs = range(len(acc2))

plt.plot(epochs, acc2, 'r', label='Training accuracy')
plt.plot(epochs, val_acc2, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

plt.plot(epochs, train_precision2, 'r', label='Training precision')
plt.plot(epochs, val_precision2, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.show()

plt.plot(epochs, train_recall2, 'r', label='Training recall')
plt.plot(epochs, val_recall2, 'b', label='Validation recall')
plt.title('Training and validation recall')
plt.legend()
plt.show()

plt.plot(epochs, loss2, 'r', label='Training Loss')
plt.plot(epochs, val_loss2, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
eval_result2 = model2.evaluate_generator(test_generator2, 624)
print('loss  :', eval_result2[0])
print('accuracy  :', eval_result2[1])
print('Precision :', eval_result2[2])
print('Recall :', eval_result2[3])
# Out:
# loss  : 0.5993345975875854
# accuracy  : 0.6650640964508057
# Precision : 0.9414634108543396
# Recall : 0.4948717951774597

# %% [markdown]
#  # Model 3 (Inception Model)
#
#  * We'll user pre-trained model provided by keras and add some layers on the top.
#  * The pre-trained Inception model in keras takes in input of exactly three input channel, but our input image is of grayscale.
#  * So inorder to avoid mismatch of shape we'll let our Image data generator use the default color_mode ie rgb instead of specifying it to be gray_scale.
#  * So we'll use same data generator as used in ResNet50 model

# %% [markdown]
# ### Importing and loading pretrained Inception model

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
pretrained_model3=InceptionV3(input_shape=(180,180,3),
                             include_top=False,
                             weights='imagenet')
#freazing the trained layers
for layers in pretrained_model3.layers:
    layers.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step

# %%
last_layer=pretrained_model3.get_layer('mixed10')
last_output = last_layer.output

# %%
x=tf.keras.layers.Flatten()(last_output)
x=tf.keras.layers.Dense(1024,activation='relu')(x)
x=tf.keras.layers.Dropout(0.2)(x)
x=tf.keras.layers.Dense(256,activation='relu')(x)
x=tf.keras.layers.Dropout(0.2)(x)
x=tf.keras.layers.Dense(1,activation='sigmoid')(x)

model3=tf.keras.Model(pretrained_model3.input,x)

model3.compile(optimizer=RMSprop(lr=0.001),
              loss='binary_crossentropy',
               metrics=['accuracy','Precision','Recall'])
# model4.summary()

# %%
history3=model3.fit(train_generator2,validation_data=val_generator2,epochs=30,verbose=2)
# Out:
# Epoch 1/30
# 33/33 - 80s - loss: 14.6075 - accuracy: 0.6863 - precision: 0.7956 - recall: 0.7758 - val_loss: 0.6469 - val_accuracy: 0.6332 - val_precision: 0.9902 - val_recall: 0.5147
# Epoch 2/30
# 33/33 - 77s - loss: 0.8522 - accuracy: 0.7830 - precision: 0.8464 - recall: 0.8639 - val_loss: 0.4670 - val_accuracy: 0.7851 - val_precision: 0.9878 - val_recall: 0.7216
# Epoch 3/30
# 33/33 - 78s - loss: 0.5201 - accuracy: 0.8022 - precision: 0.8639 - recall: 0.8700 - val_loss: 0.7584 - val_accuracy: 0.7479 - val_precision: 0.7479 - val_recall: 1.0000
# Epoch 4/30
# 33/33 - 77s - loss: 0.4311 - accuracy: 0.8404 - precision: 0.8838 - recall: 0.9032 - val_loss: 0.3368 - val_accuracy: 0.9226 - val_precision: 0.9291 - val_recall: 0.9706
# Epoch 5/30
# 33/33 - 76s - loss: 0.4290 - accuracy: 0.8456 - precision: 0.8878 - recall: 0.9061 - val_loss: 0.2279 - val_accuracy: 0.9054 - val_precision: 0.8977 - val_recall: 0.9860
# Epoch 6/30
# 33/33 - 78s - loss: 0.3636 - accuracy: 0.8648 - precision: 0.9020 - recall: 0.9171 - val_loss: 0.2355 - val_accuracy: 0.8921 - val_precision: 0.8815 - val_recall: 0.9885
# Epoch 7/30
# 33/33 - 77s - loss: 0.3266 - accuracy: 0.8810 - precision: 0.9162 - recall: 0.9239 - val_loss: 0.2233 - val_accuracy: 0.9140 - val_precision: 0.9120 - val_recall: 0.9796
# Epoch 8/30
# 33/33 - 78s - loss: 0.3562 - accuracy: 0.8750 - precision: 0.9144 - recall: 0.9171 - val_loss: 0.3346 - val_accuracy: 0.8491 - val_precision: 0.9906 - val_recall: 0.8059
# Epoch 9/30
# 33/33 - 78s - loss: 0.3195 - accuracy: 0.8815 - precision: 0.9165 - recall: 0.9242 - val_loss: 0.2476 - val_accuracy: 0.9074 - val_precision: 0.9845 - val_recall: 0.8902
# Epoch 10/30
# 33/33 - 77s - loss: 0.3090 - accuracy: 0.8927 - precision: 0.9252 - recall: 0.9303 - val_loss: 0.4226 - val_accuracy: 0.8214 - val_precision: 0.9950 - val_recall: 0.7650
# Epoch 11/30
# 33/33 - 77s - loss: 0.2865 - accuracy: 0.9027 - precision: 0.9323 - recall: 0.9368 - val_loss: 0.2854 - val_accuracy: 0.8749 - val_precision: 0.9910 - val_recall: 0.8404
# Epoch 12/30
# 33/33 - 78s - loss: 0.2882 - accuracy: 0.8987 - precision: 0.9319 - recall: 0.9313 - val_loss: 0.1986 - val_accuracy: 0.9408 - val_precision: 0.9523 - val_recall: 0.9693
# Epoch 13/30
# 33/33 - 77s - loss: 0.2296 - accuracy: 0.9075 - precision: 0.9372 - recall: 0.9381 - val_loss: 0.2068 - val_accuracy: 0.9322 - val_precision: 0.9373 - val_recall: 0.9745
# Epoch 14/30
# 33/33 - 77s - loss: 0.2466 - accuracy: 0.9171 - precision: 0.9396 - recall: 0.9490 - val_loss: 0.2219 - val_accuracy: 0.9236 - val_precision: 0.9862 - val_recall: 0.9106
# Epoch 15/30
# 33/33 - 78s - loss: 0.2531 - accuracy: 0.9118 - precision: 0.9406 - recall: 0.9403 - val_loss: 0.1977 - val_accuracy: 0.9494 - val_precision: 0.9656 - val_recall: 0.9668
# Epoch 16/30
# 33/33 - 77s - loss: 0.2541 - accuracy: 0.9109 - precision: 0.9391 - recall: 0.9406 - val_loss: 0.1567 - val_accuracy: 0.9446 - val_precision: 0.9763 - val_recall: 0.9489
# Epoch 17/30
# 33/33 - 77s - loss: 0.2786 - accuracy: 0.9099 - precision: 0.9422 - recall: 0.9358 - val_loss: 0.1714 - val_accuracy: 0.9360 - val_precision: 0.9851 - val_recall: 0.9285
# Epoch 18/30
# 33/33 - 79s - loss: 0.2182 - accuracy: 0.9228 - precision: 0.9472 - recall: 0.9487 - val_loss: 0.2374 - val_accuracy: 0.9303 - val_precision: 0.9890 - val_recall: 0.9170
# Epoch 19/30
# 33/33 - 77s - loss: 0.2367 - accuracy: 0.9128 - precision: 0.9399 - recall: 0.9426 - val_loss: 0.1522 - val_accuracy: 0.9494 - val_precision: 0.9828 - val_recall: 0.9489
# Epoch 20/30
# 33/33 - 77s - loss: 0.2493 - accuracy: 0.9214 - precision: 0.9448 - recall: 0.9494 - val_loss: 0.1552 - val_accuracy: 0.9436 - val_precision: 0.9840 - val_recall: 0.9400
# Epoch 21/30
# 33/33 - 78s - loss: 0.2550 - accuracy: 0.9264 - precision: 0.9512 - recall: 0.9494 - val_loss: 0.1463 - val_accuracy: 0.9522 - val_precision: 0.9829 - val_recall: 0.9527
# Epoch 22/30
# 33/33 - 77s - loss: 0.2230 - accuracy: 0.9233 - precision: 0.9498 - recall: 0.9465 - val_loss: 0.1404 - val_accuracy: 0.9475 - val_precision: 0.9840 - val_recall: 0.9451
# Epoch 23/30
# 33/33 - 79s - loss: 0.2361 - accuracy: 0.9183 - precision: 0.9420 - recall: 0.9481 - val_loss: 0.2113 - val_accuracy: 0.9274 - val_precision: 0.9917 - val_recall: 0.9106
# Epoch 24/30
# 33/33 - 78s - loss: 0.1918 - accuracy: 0.9295 - precision: 0.9520 - recall: 0.9529 - val_loss: 0.2784 - val_accuracy: 0.8606 - val_precision: 0.9969 - val_recall: 0.8161
# Epoch 25/30
# 33/33 - 77s - loss: 0.2428 - accuracy: 0.9211 - precision: 0.9520 - recall: 0.9410 - val_loss: 0.2398 - val_accuracy: 0.8997 - val_precision: 0.9942 - val_recall: 0.8710
# Epoch 26/30
# 33/33 - 77s - loss: 0.2244 - accuracy: 0.9219 - precision: 0.9500 - recall: 0.9442 - val_loss: 0.1637 - val_accuracy: 0.9532 - val_precision: 0.9829 - val_recall: 0.9540
# Epoch 27/30
# 33/33 - 78s - loss: 0.2424 - accuracy: 0.9168 - precision: 0.9442 - recall: 0.9435 - val_loss: 0.1349 - val_accuracy: 0.9522 - val_precision: 0.9564 - val_recall: 0.9808
# Epoch 28/30
# 33/33 - 77s - loss: 0.1995 - accuracy: 0.9324 - precision: 0.9522 - recall: 0.9568 - val_loss: 0.1704 - val_accuracy: 0.9398 - val_precision: 0.9865 - val_recall: 0.9323
# Epoch 29/30
# 33/33 - 78s - loss: 0.2048 - accuracy: 0.9252 - precision: 0.9465 - recall: 0.9529 - val_loss: 0.5981 - val_accuracy: 0.7822 - val_precision: 1.0000 - val_recall: 0.7088
# Epoch 30/30
# 33/33 - 79s - loss: 0.2156 - accuracy: 0.9238 - precision: 0.9467 - recall: 0.9506 - val_loss: 0.1319 - val_accuracy: 0.9522 - val_precision: 0.9542 - val_recall: 0.9834

# %%
acc3 = history3.history['accuracy']
val_acc3 = history3.history['val_accuracy']

train_precision3=history3.history['precision']
val_precision3=history3.history['val_precision']

train_recall3=history3.history['recall']
val_recall3=history3.history['val_recall']

loss3 = history3.history['loss']
val_loss3 = history3.history['val_loss']
epochs = range(len(acc3))

plt.plot(epochs, acc3, 'r', label='Training accuracy')
plt.plot(epochs, val_acc3, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

plt.plot(epochs, train_precision3, 'r', label='Training precision')
plt.plot(epochs, val_precision3, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.show()

plt.plot(epochs, train_recall3, 'r', label='Training recall')
plt.plot(epochs, val_recall3, 'b', label='Validation recall')
plt.title('Training and validation recall')
plt.legend()
plt.show()

plt.plot(epochs, loss3, 'r', label='Training Loss')
plt.plot(epochs, val_loss3, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
eval_result3 = model3.evaluate_generator(test_generator2, 624)
print('loss  :', eval_result3[0])
print('accuracy  :', eval_result3[1])
print('Precision :', eval_result3[2])
print('Recall :', eval_result3[3])
# Out:
# loss  : 0.4493449330329895
# accuracy  : 0.7916666865348816
# Precision : 0.75390625
# Recall : 0.9897435903549194

# %% [markdown]
# # Comparing the models
# * As this is the case of medical diagnosis accuracy cannot be the oly metric to evaluate. In medical daignosis it is very important to correctly predict the true values. We cannot incorrectly diagnose a patient as normal event after the true report of diagnosis shows that patient has pnemonia.So along with higher accuracy we need higher recall.
#
# ### Model 1 performed best with accuracy=0.8766 and recall=0.9949 on test set so we'll save this model

# %%
model.save('PNP.h5')
